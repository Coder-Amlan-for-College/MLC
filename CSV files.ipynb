# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Creating csv file

# %%
frnds ={"Name":["F1","F2","F3"],
        "Age":[20,21,22],
        "City":["C1","C2","C3"]}
df = pd.DataFrame(frnds)
df
# Out:
#   Name  Age City
# 0   F1   20   C1
# 1   F2   21   C2
# 2   F3   22   C3

# %%
df.to_csv("Friends.csv",index=False)

# %%
df2 = pd.read_csv("Friends.csv")
df2
# Out:
#   Name  Age City
# 0   F1   20   C1
# 1   F2   21   C2
# 2   F3   22   C3

# %% [markdown]
# ### Reading csv from internet

# %%
import pandas as pd

# Define column names from UCI Auto MPG dataset
column_names = [
    "mpg", "cylinders", "displacement", "horsepower", "weight",
    "acceleration", "model_year", "origin", "car_name"
]

# URL of Auto MPG dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"

# Load dataset
df = pd.read_csv(
    url,
    sep='\s+',   # data separated by spaces
    names=column_names,      # assign column names
    na_values="?"            # missing values marked as '?'
)

# Save to local CSV file
df.to_csv("auto_mpg.csv", index=False)

print("✅ Auto MPG dataset saved as 'auto_mpg.csv'")
print(df.head())
# Out:
# ✅ Auto MPG dataset saved as 'auto_mpg.csv'
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin                   car_name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
url = "https://support.staffbase.com/hc/en-us/article_attachments/360009197031/username.csv"
df3 = pd.read_csv(url,sep=";")
df3.head(10)
# Out:
#     Username   Identifier First name Last name
# 0   booker12         9012     Rachel    Booker
# 1     grey07         2070      Laura      Grey
# 2  johnson81         4081      Craig   Johnson
# 3  jenkins46         9346       Mary   Jenkins
# 4    smith79         5079      Jamie     Smith

# %%
import pandas as pd

# Define column names from UCI Auto MPG dataset
column_names = [
    "mpg", "cylinders", "displacement", "horsepower", "weight",
    "acceleration", "model_year", "origin", "car_name"
]

# URL of Auto MPG dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"

# Load dataset
df = pd.read_csv(
    url,
    sep='\s+',   # data separated by spaces
    names=column_names,      # assign column names
    na_values="?"            # missing values marked as '?'
)

# Save to local CSV file
df.to_csv("auto_mpg.csv", index=False)

print("✅ Auto MPG dataset saved as 'auto_mpg.csv'")
print(df.head())
# Out:
# ✅ Auto MPG dataset saved as 'auto_mpg.csv'
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin                   car_name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.head(50)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0      130.0  3504.0          12.0
# 1   15.0          8         350.0      165.0  3693.0          11.5
# 2   18.0          8         318.0      150.0  3436.0          11.0
# 3   16.0          8         304.0      150.0  3433.0          12.0
# 4   17.0          8         302.0      140.0  3449.0          10.5
# 5   15.0          8         429.0      198.0  4341.0          10.0
# 6   14.0          8         454.0      220.0  4354.0           9.0
# 7   14.0          8         440.0      215.0  4312.0           8.5
# 8   14.0          8         455.0      225.0  4425.0          10.0
# 9   15.0          8         390.0      190.0  3850.0           8.5
# 10  15.0          8         383.0      170.0  3563.0          10.0
# 11  14.0          8         340.0      160.0  3609.0           8.0
# 12  15.0          8         400.0      150.0  3761.0           9.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe() #only applicable for numerical data
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe(percentiles=[0.3,0.5,0.75])
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 30%     18.000000    4.000000    112.000000  2301.000000     14.200000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 30%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['car_name'].describe()#categorical data
# Out:
# count            398
# unique           305
# top       ford pinto
# freq               6
# Name: car_name, dtype: object

# %%
df.describe(include="all")#works for both numeric and non-numeric data
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN      150.0          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model_year      origin    car_name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
df.shape #shows rows and columns o/p is in tuple form
# Out:
# (398, 9)

# %%
df.shape[0]#represents rows
# Out:
# 398

# %%
df.shape[1]#represents cols
# Out:
# 9

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'car_name'],
#       dtype='object')

# %%
lst = list(df.columns)
lst
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model_year',
#  'origin',
#  'car_name']

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %% [markdown]
# # Dealing with duplicated values

# %%
data = {
    "Name":['A','B','A','C','B','D','A','B','A','C','B','D'],
    "Age":[25,30,25,35,30,40,25,30,25,35,30,40],
    "City":["C1","C2","C1","C3","C2","C4","C1","C2","C1","C3","C2","C4"]
}
dfdp = pd.DataFrame(data)
dfdp
# Out:
#    Name  Age City
# 0     A   25   C1
# 1     B   30   C2
# 2     A   25   C1
# 3     C   35   C3
# 4     B   30   C2
# 5     D   40   C4
# 6     A   25   C1
# 7     B   30   C2
# 8     A   25   C1
# 9     C   35   C3
# 10    B   30   C2
# 11    D   40   C4

# %%
dfdp.duplicated()#shows True
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# dtype: bool

# %%
dfdp.drop_duplicates()#keeps the first duplicated value and removes the others(by default keep="first")
# Out:
#   Name  Age City
# 0    A   25   C1
# 1    B   30   C2
# 3    C   35   C3
# 5    D   40   C4

# %%
dfdp.drop_duplicates(keep='last')#keeps the last duplicated value and removes the others
# Out:
#    Name  Age City
# 8     A   25   C1
# 9     C   35   C3
# 10    B   30   C2
# 11    D   40   C4

# %%
#show only the unique values
dfdp.drop_duplicates(keep=False)
# Out:
# Empty DataFrame
# Columns: [Name, Age, City]
# Index: []

# %%
#inplace=True
dfdp.drop_duplicates(inplace = True)
dfdp
# Out:
#   Name  Age City
# 0    A   25   C1
# 1    B   30   C2
# 3    C   35   C3
# 5    D   40   C4

# %% [markdown]
# ## Removing the particular duplicated values

# %%
data = {"Name":["N1","N2","N3","N4","N5","N1","N3"],
       "Age":[25,26,25,26,27,25,25],
       "Sec":["G1","G1","G2","G3","G4","G6","G5"]}
df = pd.DataFrame(data)
df
# Out:
#   Name  Age Sec
# 0   N1   25  G1
# 1   N2   26  G1
# 2   N3   25  G2
# 3   N4   26  G3
# 4   N5   27  G4
# 5   N1   25  G6
# 6   N3   25  G5

# %%
#no duplicate age
df.drop_duplicates(subset=['Age'])
# Out:
#   Name  Age Sec
# 0   N1   25  G1
# 1   N2   26  G1
# 4   N5   27  G4

# %%
#no duplicate age and name
df.drop_duplicates(subset=["Name","Age"])
# Out:
#   Name  Age Sec
# 0   N1   25  G1
# 1   N2   26  G1
# 2   N3   25  G2
# 3   N4   26  G3
# 4   N5   27  G4

# %%
df.drop_duplicates(subset=['Age'],keep=False)
# Out:
#   Name  Age Sec
# 4   N5   27  G4

# %%
#show unique names
names = df.drop_duplicates(subset=['Name'],keep=False)
names
# Out:
#   Name  Age Sec
# 1   N2   26  G1
# 3   N4   26  G3
# 4   N5   27  G4

# %%
print(df['Name'].drop_duplicates(keep=False))
# Out:
# 1    N2
# 3    N4
# 4    N5
# Name: Name, dtype: object

# %% [markdown]
# ## Dealing with missing values

# %%
data = {"Name":["N1","N2","N3","N4","N5","N6",np.NaN],
       "Age":[25,26,25,np.NaN,27,25,25],
       "Sec":["G1","G1","G2","G3","G4",np.NaN,"G5"]}
df = pd.DataFrame(data)
df
# Out:
#   Name   Age  Sec
# 0   N1  25.0   G1
# 1   N2  26.0   G1
# 2   N3  25.0   G2
# 3   N4   NaN   G3
# 4   N5  27.0   G4
# 5   N1  25.0  NaN
# 6  NaN  25.0   G5

# %%
df.isna() #where null value exist it will show True
# Out:
#     Name    Age    Sec
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False   True  False
# 4  False  False  False
# 5  False  False   True
# 6   True  False  False

# %%
df.isna().sum()#counts the total no. of null values in each columns
# Out:
# Name    1
# Age     1
# Sec     1
# dtype: int64

# %% [markdown]
# ### Drop the rows with NaN values

# %%
dfn = df.dropna()#removes the rows with null values
dfn
# Out:
#   Name   Age Sec
# 0   N1  25.0  G1
# 1   N2  26.0  G1
# 2   N3  25.0  G2
# 4   N5  27.0  G4

# %%
#drop the null value of a specific col
dfc = df.dropna(subset=['Name'])
dfc
# Out:
#   Name   Age  Sec
# 0   N1  25.0   G1
# 1   N2  26.0   G1
# 2   N3  25.0   G2
# 3   N4   NaN   G3
# 4   N5  27.0   G4
# 5   N1  25.0  NaN

# %% [markdown]
# ## Filling the NaN values

# %%
fill = df.copy()
fill
# Out:
#   Name   Age  Sec
# 0   N1  25.0   G1
# 1   N2  26.0   G1
# 2   N3  25.0   G2
# 3   N4   NaN   G3
# 4   N5  27.0   G4
# 5   N1  25.0  NaN
# 6  NaN  25.0   G5

# %%
fill['Name'].fillna("unknown",inplace=True)
fill['Age'].fillna(0,inplace=True)
fill['Sec'].fillna("not defined",inplace=True)
fill
# Out:
#       Name   Age          Sec
# 0       N1  25.0           G1
# 1       N2  26.0           G1
# 2       N3  25.0           G2
# 3       N4   0.0           G3
# 4       N5  27.0           G4
# 5       N1  25.0  not defined
# 6  unknown  25.0           G5
