# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

X = np.array([[1,2],[2,3],[3,3],[6,5],[7,7],[8,6]])
Y = np.array([0,0,0,1,1,1])

k=3
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X,Y)

sample = np.array([[6,5]])
predicted_class = knn.predict(sample)
print("Predicted class for [6,5]:",predicted_class)
# Out:
# Predicted class for [6,5]: [1]

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("btissue.csv")

X = df.iloc[:,:-1]
Y = df.iloc[:,-1]
X.shape
# Out:
# (106, 9)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

print("Train Shape:",x_train.shape)
print("Test Shape:",x_test.shape)
# Out:
# Train Shape: (84, 9)
# Test Shape: (22, 9)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

knn = KNeighborsClassifier(n_neighbors=3)

model = knn.fit(x_train,y_train)

pred = knn.predict(x_test)

print("Accuracy:",accuracy_score(y_test,pred))
print("Precision score:",precision_score(y_test,pred, average='macro',zero_division=0))
print("Recall:",recall_score(y_test,pred,average="macro",zero_division=0))
print("F1-score:",recall_score(y_test,pred,average="macro",zero_division=0))
# Out:
# Accuracy: 0.6818181818181818
# Precision score: 0.7261904761904763
# Recall: 0.6527777777777778
# F1-score: 0.6527777777777778

# %%
cm = confusion_matrix(y_test,pred)
plt.figure(figsize=(4,3))
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_depth=5,random_state=42)
dtc.fit(x_train,y_train)
pred = dtc.predict(x_test)

print("Accuracy:",accuracy_score(y_test,pred))
print("Precision score:",precision_score(y_test,pred, average='macro',zero_division=0))
print("Recall:",recall_score(y_test,pred,average="macro",zero_division=0))
print("F1-score:",recall_score(y_test,pred,average="macro",zero_division=0))
# Out:
# Accuracy: 0.7727272727272727
# Precision score: 0.7222222222222222
# Recall: 0.6944444444444445
# F1-score: 0.6944444444444445

# %%
cm = confusion_matrix(y_test,pred)
plt.figure(figsize=(4,3))
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=5,random_state=42)
rf.fit(x_train,y_train)
pred = rf.predict(x_test)

print("Accuracy:",accuracy_score(y_test,pred))
print("Precision score:",precision_score(y_test,pred, average='macro',zero_division=0))
print("Recall:",recall_score(y_test,pred,average="macro",zero_division=0))
print("F1-score:",recall_score(y_test,pred,average="macro",zero_division=0))

cm = confusion_matrix(y_test,pred)
plt.figure(figsize=(4,3))
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.8181818181818182
# Precision score: 0.8444444444444446
# Recall: 0.7777777777777778
# F1-score: 0.7777777777777778
